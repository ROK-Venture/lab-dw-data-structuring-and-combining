# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# Your code goes here
import pandas as pd

# %%
url_1 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'

df_insurance_1 = pd.read_csv(url_1)
df_insurance_1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
url_2 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv'

df_insurance_2 = pd.read_csv(url_2)
df_insurance_2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
url_3 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv'

df_insurance_3 = pd.read_csv(url_3)
df_insurance_3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df_insurance_1.columns = [col.lower().strip() for col in df_insurance_1.columns]

# %%
df_insurance_2.columns = [col.lower().strip() for col in df_insurance_2.columns]

# %%
df_insurance_3.columns = [col.lower().strip() for col in df_insurance_3.columns]

# %%
df_insurance_1.rename(columns = {"st": "state"}, inplace = True)
df_insurance_1.head()
# Out:
#   customer       state gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
df_insurance_2.rename(columns = {"st": "state"}, inplace = True)
df_insurance_2.head()
# Out:
#   customer       state gender education customer lifetime value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly premium auto number of open complaints  total claim amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       policy type  vehicle class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
df_insurance_3.head()
# Out:
#   customer       state  customer lifetime value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    total claim amount  vehicle class
# ...

# %%
df_insurance_merge = pd.concat([df_insurance_1, df_insurance_2, df_insurance_3], axis = 0, join = "outer").reset_index(drop = True)

df_insurance_merge
# Out:
#       customer       state gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %%
df_insurance_merge.isnull().sum()
# Out:
# customer                     2937
# state                        2937
# gender                       3059
# education                    2937
# customer lifetime value      2944
# income                       2937
# monthly premium auto         2937
# number of open complaints    2937
# policy type                  2937
# vehicle class                2937
# total claim amount           2937
# dtype: int64

# %%
df_insurance_clean_null = df_insurance_merge.dropna(how="all", subset =["customer"])

df_insurance_clean_null.isnull().sum()
# Out:
# customer                       0
# state                          0
# gender                       122
# education                      0
# customer lifetime value        7
# income                         0
# monthly premium auto           0
# number of open complaints      0
# policy type                    0
# vehicle class                  0
# total claim amount             0
# dtype: int64

# %%
df_insurance_clean_null["customer"].duplicated().sum()
# Out:
# 81

# %%
df_insurance_clean_duplicat = df_insurance_clean_null.drop_duplicates(subset = ["customer"]).reset_index(drop = True)

df_insurance_clean_duplicat
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 9051  LA72316  California      M              Bachelor
# 9052  PK87824  California      F               College
# 9053  TD14365  California      M              Bachelor
# 9054  UP19263  California      M               College
# 9055  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df_insurance_clean_duplicat.isnull().sum() # dont go for null values in gender beacause there are the only missing value in an almost complete datapoint/row
# Out:
# customer                       0
# state                          0
# gender                       122
# education                      0
# customer lifetime value        7
# income                         0
# monthly premium auto           0
# number of open complaints      0
# policy type                    0
# vehicle class                  0
# total claim amount             0
# dtype: int64

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here


url_marketing = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv'

df_insurance_marketing = pd.read_csv(url_marketing)
df_insurance_marketing
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
df_insurance_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   unnamed:_0                     10910 non-null  int64
#  1   customer                       10910 non-null  object
#  2   state                          10910 non-null  object
#  3   customer_lifetime_value        10910 non-null  float64
#  4   response                       10910 non-null  object
#  5   coverage                       10910 non-null  object
#  6   education                      10910 non-null  object
#  7   effective_to_date              10910 non-null  object
#  8   employmentstatus               10910 non-null  object
#  9   gender                         10910 non-null  object
#  10  income                         10910 non-null  int64
#  11  location_code                  10910 non-null  object
# ...

# %%
df_insurance_marketing.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type', 'month'],
#       dtype='object')

# %%
#reducing the dataframe to the important facts
df_insurance_marketing.drop(columns = ['unnamed:_0', 'state', 'response', 'effective_to_date',
       'employmentstatus', 'income', 'location_code', 'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
       'months_since_policy_inception', 'number_of_open_complaints', 'number_of_policies', 'policy', 'renew_offer_type', 
       'vehicle_class', 'vehicle_size', 'vehicle_type', 'month'], inplace=True)

df_insurance_marketing.head()
# Out:
#   customer  customer_lifetime_value  coverage education gender  \
# 0  DK49336              4809.216960     Basic   College      M
# 1  KX64629              2228.525238     Basic   College      F
# 2  LZ68649             14947.917300     Basic  Bachelor      M
# 3  XL78013             22332.439460  Extended   College      M
# 4  QA50777              9025.067525   Premium  Bachelor      F
#
#       policy_type sales_channel  total_claim_amount
# 0  Corporate Auto         Agent          292.800000
# 1   Personal Auto   Call Center          744.924331
# 2   Personal Auto   Call Center          480.000000
# 3  Corporate Auto        Branch          484.013411
# 4   Personal Auto        Branch          707.925645

# %%
df_insurance_marketing.isnull().sum()
# Out:
# customer                   0
# customer_lifetime_value    0
# coverage                   0
# education                  0
# gender                     0
# policy_type                0
# sales_channel              0
# total_claim_amount         0
# dtype: int64

# %%
df_insurance_marketing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer                 10910 non-null  object
#  1   customer_lifetime_value  10910 non-null  float64
#  2   coverage                 10910 non-null  object
#  3   education                10910 non-null  object
#  4   gender                   10910 non-null  object
#  5   policy_type              10910 non-null  object
#  6   sales_channel            10910 non-null  object
#  7   total_claim_amount       10910 non-null  float64
# dtypes: float64(2), object(6)
# memory usage: 682.0+ KB

# %%
df_insurance_marketing["gender"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df_insurance_marketing["education"].unique()
# Out:
# array(['College', 'Bachelor', 'High School or Below', 'Doctor', 'Master'],
#       dtype=object)

# %%
df_insurance_marketing["sales_channel"].unique()
# Out:
# array(['Agent', 'Call Center', 'Branch', 'Web'], dtype=object)

# %%
df_insurance_marketing["policy_type"].unique()
# Out:
# array(['Corporate Auto', 'Personal Auto', 'Special Auto'], dtype=object)

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
pivot_df_sales = df_insurance_marketing.pivot_table(index='sales_channel', values=['total_claim_amount'], aggfunc='sum').round(2)

pivot_df_sales
# Out:
#                total_claim_amount
# sales_channel
# Agent                  1810226.82
# Branch                 1301204.00
# Call Center             926600.82
# Web                     706600.04

# %% [markdown]
# # <span style="color:green">Insight by Robert: The agent sales channel generates the most sales. In terms of sales, this sales channel is more than twice as strong as the poor sales channel Web. However, this does not indicate which channel is the best in terms of costs. Only measured in terms of absolute turnover</span>

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
pivot_df_ltv = df_insurance_marketing.pivot_table(index='gender', columns='education', values=['customer_lifetime_value'], aggfunc='mean').round(2)

pivot_df_ltv
# Out:
#           customer_lifetime_value                                         \
# education                Bachelor  College   Doctor High School or Below
# gender
# F                         7874.27  7748.82  7328.51              8675.22
# M                         7703.60  8052.46  7415.33              8149.69
#
#
# education   Master
# gender
# F          8157.05
# M          8168.83

# %% [markdown]
# # <span style="color:green">Insight by Robert: The insurance company has the best customer lifetime value with people who have a high school diploma or less. These customers generally seem to be less likely to change insurance and sales should generally focus on this customer group. However, it remains to be clarified whether this group is also the most profitable group, as no claims caused have been taken into account here, which may have to be considered additionally</span>

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
